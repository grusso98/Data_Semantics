# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -U CADE
# !pip install git+https://github.com/valedica/gensim.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/valedica/gensim.git to /tmp/pip-req-build-4m246jsi
#   Running command git clone -q https://github.com/valedica/gensim.git /tmp/pip-req-build-4m246jsi
# ...

# %%
import os
os.chdir('/content/drive/MyDrive/DataSemantics/progetto/')

# %%
from cade.cade import CADE
from gensim.models.word2vec import Word2Vec
from scipy.spatial.distance import cosine

# %%
# !cat past_lem.txt post_lem.txt > total_lem.txt

# %%
aligner_lem = CADE(size = 100)
aligner_lem.train_compass("total_lem.txt")
# Out:
# Training the compass from scratch.
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:410: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
slice_past_lem = aligner_lem.train_slice("past_lem.txt")
slice_post_lem = aligner_lem.train_slice("post_lem.txt")
# Out:
# Training embeddings: slice past_lem.txt.
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:410: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# Initializing embeddings from compass.
# Training embeddings: slice post_lem.txt.
# Initializing embeddings from compass.

# %%
if not os.path.exists('/content/drive/MyDrive/DataSemantics/progetto/models/CADE'):
    os.makedirs('/content/drive/MyDrive/DataSemantics/progetto/models/CADE')

# %%
slice_past_lem.save('/content/drive/MyDrive/DataSemantics/progetto/models/CADE/past_lem_aligned.model')
# Out:
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:410: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
slice_post_lem.save('/content/drive/MyDrive/DataSemantics/progetto/models/CADE/post_lem_aligned.model')
# Out:
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:410: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# Window 5 BG

# %%
aligner_lem_bg = CADE(size = 100)
aligner_lem_bg.train_compass("total_lem_bg.txt")
# Out:
# Training the compass from scratch.
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:410: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
slice_past_lem_bg = aligner_lem_bg.train_slice("past_lem_bg.txt")
slice_post_lem_bg = aligner_lem_bg.train_slice("post_lem_bg.txt")
# Out:
# Training embeddings: slice past_lem_bg.txt.
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:410: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# Initializing embeddings from compass.
# Training embeddings: slice post_lem_bg.txt.
# Initializing embeddings from compass.

# %%
if not os.path.exists('/content/drive/MyDrive/DataSemantics/progetto/models/CADE'):
    os.makedirs('/content/drive/MyDrive/DataSemantics/progetto/models/CADE')

# %%
slice_past_lem_bg.save('/content/drive/MyDrive/DataSemantics/progetto/models/CADE/past_lem_bg_aligned.model')
# Out:
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:410: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
slice_post_lem_bg.save('/content/drive/MyDrive/DataSemantics/progetto/models/CADE/post_lem_bg_aligned.model')
# Out:
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:410: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# Window 5 Bigrams: NON  utilizzato perchè il bigram heavenly_virtue non è presente in post e i risultati sono pressochè simili o con la presenza di bigrams non sensati

# %% [markdown]
# Window 5 SKIPGRAM

# %%
aligner_lem_skip = CADE(size = 100,sg=1)
aligner_lem_skip.train_compass("total_lem.txt")
# Out:
# Training the compass from scratch.
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:410: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
aligner_lem_skip

# %%
slice_past_lem_skip = aligner_lem_skip.train_slice("past_lem.txt")
slice_post_lem_skip = aligner_lem_skip.train_slice("post_lem.txt")
# Out:
# Training embeddings: slice past_lem.txt.
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:410: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# Initializing embeddings from compass.
# Training embeddings: slice post_lem.txt.
# Initializing embeddings from compass.

# %%
slice_past_lem_skip.save('/content/drive/MyDrive/DataSemantics/progetto/models/CADE/past_lem_skip_aligned.model')
# Out:
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:410: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
slice_post_lem_skip.save('/content/drive/MyDrive/DataSemantics/progetto/models/CADE/post_lem_skip_aligned.model')
# Out:
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:410: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# Window 3

# %%
aligner_lem_3 = CADE(size = 100,window=3)
aligner_lem_3.train_compass("total_lem.txt")
# Out:
# Training the compass from scratch.
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:410: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
slice_past_lem_3 = aligner_lem_3.train_slice("past_lem.txt")
slice_post_lem_3 = aligner_lem_3.train_slice("post_lem.txt")
# Out:
# Training embeddings: slice past_lem.txt.
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:410: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# Initializing embeddings from compass.
# Training embeddings: slice post_lem.txt.
# Initializing embeddings from compass.

# %%
slice_past_lem_3.save('/content/drive/MyDrive/DataSemantics/progetto/models/CADE/past_lem_aligned_3.model')
# Out:
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:410: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
slice_post_lem_3.save('/content/drive/MyDrive/DataSemantics/progetto/models/CADE/post_lem_aligned_3.model')
# Out:
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:410: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
